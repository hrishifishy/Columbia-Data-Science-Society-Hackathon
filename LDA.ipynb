# 1328        1328  https://www.bloomberg.com/news/articles/2018-0...
# 1329        1329  https://www.bloomberg.com/news/articles/2018-0...
# 1330        1330  https://www.bloomberg.com/news/articles/2018-0...
# 1331        1331  http://www.arkansasonline.com/news/2017/jun/29...
# 1332        1332  http://www.arkansasonline.com/news/2017/jul/20...
# 1333        1333  http://www.arkansasonline.com/news/2018/feb/08...
# 1334        1334  http://www.arkansasonline.com/news/2018/jul/22...
#
#                                                    text
# 0     This material may not be published, broadcast,...
# 1     This material may not be published, broadcast,...
# 2     Small business optimism rose in May to its hig...
# 3     There has been a lot of discussion around glob...
# 4      PoliticsAnalysis EconomyCommentary EconomyCom...
# 5     The Obama administration prosecuted approximat...
# 6     \n                Access to this page has been...
# 7       As Washington continues to reel from the fai...
# 8     \n                Access to this page has been...
# 9       Would you expect a 1986 automobile to be pra...
# 10    Healthy business organizations are designed to...
# 11    The recent crisis at the border surrounding so...
# 12     PoliticsAnalysis EconomyCommentary EconomyCom...
# 13    National Review \n\t\t\t\t\t\t\t\n\t\t\t\t\t\t...
# 14    As we approach Labor Day this year, the Americ...
# 15    Last\n          Updated Sep 24, 2018 2:37 PM E...
# 16    Thanks for contacting us. We've received your ...
# 17     PoliticsAnalysis EconomyCommentary EconomyCom...
# 18    President TrumpDonald John TrumpTop consumer b...
# 19    President TrumpDonald John TrumpTop consumer b...
# 20    Tax cuts are “Armageddon” and “the worst bill ...
# 21    Thanks for contacting us. We've received your ...
# 22    Thanks for contacting us. We've received your ...
# 23    This material may not be published, broadcast,...
# 24    This material may not be published, broadcast,...
# 25    Advertisement Supported by By Clifford Krauss ...
# 26    Advertisement Supported by By Clifford Krauss ...
# 27    Baltimore-based developer St. John Properties ...
# 28     Settings Cancel Set Hi  Already a subscriber?...
# 29     Settings Cancel Set Hi  Already a subscriber?...
# ...                                                 ...
# 1305  Your usage has been flagged as a violation of ...
# 1306  Your usage has been flagged as a violation of ...
# 1307  Your usage has been flagged as a violation of ...
# 1308  Your usage has been flagged as a violation of ...
# 1309  Your usage has been flagged as a violation of ...
# 1310  Your usage has been flagged as a violation of ...
# 1311  Your usage has been flagged as a violation of ...
# 1312  Your usage has been flagged as a violation of ...
# 1313  Your usage has been flagged as a violation of ...
# 1314  Your usage has been flagged as a violation of ...
# 1315  Your usage has been flagged as a violation of ...
# 1316  Your usage has been flagged as a violation of ...
# 1317  Your usage has been flagged as a violation of ...
# 1318  Your usage has been flagged as a violation of ...
# 1319  Your usage has been flagged as a violation of ...
# 1320  Your usage has been flagged as a violation of ...
# 1321  Your usage has been flagged as a violation of ...
# 1322  Your usage has been flagged as a violation of ...
# 1323  Your usage has been flagged as a violation of ...
# 1324  Your usage has been flagged as a violation of ...
# 1325  Your usage has been flagged as a violation of ...
# 1326  Your usage has been flagged as a violation of ...
# 1327  Your usage has been flagged as a violation of ...
# 1328  Your usage has been flagged as a violation of ...
# 1329  Your usage has been flagged as a violation of ...
# 1330  Your usage has been flagged as a violation of ...
# 1331  Bugs Bunny, that font of wisdom, once tried to...
# 1332  On Tuesday, after other Republican senators to...
# 1333  In December, Congress passed and President Tru...
# 1334  Aside from matters of war and peace, arguably ...
#
# [1335 rows x 3 columns]

# %%
wordnet = WordNetLemmatizer()
i=0
stopWords = set(stopwords.words('english'))
with open('clean3.csv', 'w',encoding="utf-8") as writer:
    with open('west_wing_reads.csv','rb') as data:
        spamwriter = csv.writer(writer, delimiter=' ', quotechar='|', quoting=csv.QUOTE_MINIMAL)
        articles= pd.read_csv(data)
        for i in range(1335):
            if i==1334:
                word = word_tokenize(str(articles.extracted_keywords[i]))
                word=[words.lower() for words in word if words.isalpha()]
                wordsFiltered = []
                for w in word:
                    if w not in stopWords:
                        w = wordnet.lemmatize(w)
                        wordsFiltered.append(w)
                spamwriter.writerow(wordsFiltered)  
                break
            if(articles.extracted_keywords[i]==articles.extracted_keywords[i+1]):
                continue
            word = word_tokenize(str(articles.extracted_keywords[i]))
            word=[words.lower() for words in word if words.isalpha()]
            wordsFiltered = []
            for w in word:
                if w not in stopWords:
                    w = wordnet.lemmatize(w)
                    wordsFiltered.append(w)
            spamwriter.writerow(wordsFiltered)
            i=i+1
        
print("complete")
# Out:
# complete

# %%
df = pd.read_csv('clean2.csv')
df.shape
# Out:
# (1243, 1)

# %%
import csv
from sklearn.feature_extraction.text import TfidfVectorizer
with open('clean2.csv') as dataset:
    articles = pd.read_csv(dataset)
    vectorizer = TfidfVectorizer()
    tfidf = vectorizer.fit_transform(articles)
# Out:
# (1, 32)

# %%
import gensim

import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np

# %%
wordnet = WordNetLemmatizer()
i=0
stopWords = set(stopwords.words('english'))
with open('clean_freq_group.csv', 'w',encoding="utf-8") as writer:
    with open('month_grouped.csv','rb') as data:
        spamwriter = csv.writer(writer, delimiter=' ', quotechar='|', quoting=csv.QUOTE_MINIMAL)
        articles= pd.read_csv(data)
        for i in range(16):
            word = word_tokenize(str(articles.title[i]))
            word=[words.lower() for words in word if words.isalpha()]
            wordsFiltered = []
            for w in word:
                if w not in stopWords:
                    w = wordnet.lemmatize(w)
                    wordsFiltered.append(w)
            spamwriter.writerow(wordsFiltered)
            i=i+1
        
print("complete")
# Out:
# complete

# %%
from collections import Counter
df2=pd.read_csv('clean_freq_group.csv')
a=df2.title.iloc[14].split(' ')
b=dict(Counter(a))
d=dict(Counter(a).most_common(15))
print(d)
# Out:
# {'supreme': 6, 'since': 5, 'cut': 5, 'want': 5, 'better': 5, 'kavanaugh': 15, 'american': 6, 'new': 9, 'tax': 5, 'brett': 6, 'america': 8, 'ice': 6, 'business': 7, 'trump': 22, 'million': 5}

# %%
import matplotlib.pyplot as plt
plt.bar(range(len(d)), d.values(), align="center")
plt.xticks(range(len(d)), list(d.keys()))
plt.title('July 2018')
plt.show()

# %%
wordnet = WordNetLemmatizer()
i=0
stopWords = set(stopwords.words('english'))
with open('trend_freq_group.csv', 'w',encoding="utf-8") as writer:
    with open('trends_grouped.csv','rb') as data:
        spamwriter = csv.writer(writer, delimiter=' ', quotechar='|', quoting=csv.QUOTE_MINIMAL)
        articles= pd.read_csv(data)
        for i in range(12):
            word = word_tokenize(str(articles.trend[i]))
            word=[words.lower() for words in word if words.isalpha()]
            wordsFiltered = []
            for w in word:
                if w not in stopWords:
                    w = wordnet.lemmatize(w)
                    wordsFiltered.append(w)
            spamwriter.writerow(wordsFiltered)
            i=i+1
        
print("complete")
# Out:
# complete

# %%
nltk.download('averaged_perceptron_tagger')
from collections import Counter
df2=pd.read_csv('trend_freq_group.csv')
a=df2.trend.iloc[2].split(' ')
pos=nltk.pos_tag(a)
a=[s for s in pos if s[1] != ('NN')]
l=dict(Counter(a).most_common(10))
l
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/hrishikeshtelang/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# {('danny', 'JJ'): 3,
#  ('gary', 'JJ'): 4,
#  ('green', 'JJ'): 3,
#  ('james', 'NNS'): 4,
#  ('jones', 'NNS'): 4,
#  ('sean', 'JJ'): 4,
#  ('thursdaythoughts', 'NNS'): 4,
#  ('west', 'JJS'): 4,
#  ('williams', 'NNS'): 5,
#  ('young', 'JJ'): 4}
